# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Mounted at gdrive

# %%
cd '/content/gdrive/MyDrive/Colab Notebooks/BIG_PY_2022/'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/BIG_PY_2022

# %%
# !echo "# 2022_BIG_PY" >> README.md
# !git init
# !git config --global user.email "isdiscodead@korea.ac.kr"
# !git config --global user.name "isdiscodead"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://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@github.com/isdiscodead/BIG_PY_2022.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab Notebooks/BIG_PY_2022/.git/
# [main 944d533] first commit
#  1 file changed, 1 insertion(+)
# fatal: remote origin already exists.
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git config --global user.email "isdiscodead@korea.ac.kr"
# !git config --global user.name "isdiscodead"
# !git add .
# !git commit -m "test"
# !git push origin main
